# %%
# Download pandas in the Jupyer kernel enviornment
import sys
print(sys.executable) # Shows the python path jupyter is using

# Run path-from-above -m pip install pandas
# Out:
# /mnt/c/Users/thegl/SmartMarket/.venv/bin/python

# %%
import pandas as pd

df = pd.read_csv('../data/perishable_goods_management.csv')
df.head(20) # Output the first 20 records
# Out:
#     record_id   product_id    product_name         category   store_id  \
# 0           1  BAK_DON_743          Donuts           Bakery  STORE_046
# 1           2  MEA_SAU_338        Sausages             Meat  STORE_030
# 2           3  BAK_BAG_799          Bagels           Bakery  STORE_035
# 3           4  PHA_VAC_801        Vaccines  Pharmaceuticals  STORE_003
# 4           5  REA_FRE_422     Fresh Pasta     Ready_to_Eat  STORE_042
# 5           6  PHA_EYE_369       Eye Drops  Pharmaceuticals  STORE_026
# 6           7  BEV_FRE_873     Fresh Juice        Beverages  STORE_041
# 7           8  FRO_FRO_710  Frozen Dinners     Frozen_Meals  STORE_036
# 8           9  PHA_ANT_887     Antibiotics  Pharmaceuticals  STORE_019
# 9          10  BAK_CRO_880      Croissants           Bakery  STORE_041
# 10         11  SEA_TUN_880            Tuna          Seafood  STORE_001
# 11         12  DEL_SAL_345          Salami             Deli  STORE_006
# ...
